# %% [markdown]
# ## Exploring the Awfulness of the Miami Dolphins

# %% [markdown]
# ![Infographic.png](attachment:cd381c29-65a1-4226-9e4d-183b45815c28.png)

# %% [markdown]
# Using data from NFl databases, I created an infographic exploring why the Miami Dolphins are so bad, using quarterback stats across the league. I explore stats such as passer rating, team win percentage, passing touchdowns thrown, interceptions thrown, completion percentage, and TD/INT ratio. I compare some of these stats to the rest of the league by finding what percentile the dolphins are in as well as comparing to league averages. The graphic includes 4 plots, 3 of which are line plots and 1 being a heatmap. My freeform element is located in the bottom right, reinforcing my message.

# %% [markdown]
# ## Project Resource Manifest
#
# | Name | Type | Description | Link |
# |------|------|-------------|------|
# | qb_data_cleaned.csv | Data File | Cleaned NFL QB stats (main analysis source) | https://github.com/kbr8ey/Design-Final-Project/blob/main/Data/qb_data_cleaned.csv |
# | qb_data(in).csv | Data File | Raw NFL QB stats (original source) | https://github.com/kbr8ey/Design-Final-Project/blob/main/Data/qb_data(in).csv |
# | miami_qb_data.csv | Data File | Miami Dolphins QB ratings by year | https://github.com/kbr8ey/Design-Final-Project/blob/main/miami_qb_data.csv |
# | Infographic.png | Image | Final infographic visualizing Dolphins' performance | https://github.com/kbr8ey/Design-Final-Project/blob/main/Infographic.png |
# | Establish.ipynb | Notebook | Data acquisition and initial setup | https://github.com/kbr8ey/Design-Final-Project/blob/main/Establish.ipynb |
# | Explore.ipynb | Notebook | Data exploration and cleaning | https://github.com/kbr8ey/Design-Final-Project/blob/main/Explore.ipynb |
# | Final.ipynb | Notebook | Final summary and infographic presentation | https://github.com/kbr8ey/Design-Final-Project/blob/main/Final.ipynb |
# | NFL Player Stats (Pro Football Reference) | External | Source for NFL player statistics | https://www.pro-football-reference.com/ |
